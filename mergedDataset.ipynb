# %% [markdown]
# <a href="https://colab.research.google.com/github/brindanaveen0109/FlickPicks/blob/main/mergedDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.read_csv("/content/movies.csv")
df2 = pd.read_csv("/content/ratings.csv")

# %%
df1
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
df2
# Out:
#         userId  movieId  rating     timestamp
# 0            1      296     5.0  1.147880e+09
# 1            1      306     3.5  1.147869e+09
# 2            1      307     5.0  1.147869e+09
# 3            1      665     5.0  1.147879e+09
# 4            1      899     3.5  1.147869e+09
# ...        ...      ...     ...           ...
# 169204    1203    57528     0.5  1.485639e+09
# 169205    1203    58025     3.5  1.437579e+09
# 169206    1203    58301     4.5  1.437579e+09
# 169207    1203    58315     3.5  1.421540e+09
# 169208    1203    58485     4.5           NaN
#
# [169209 rows x 4 columns]

# %%
mergedf = pd.merge(df1, df2, on = "movieId")

# %%
mergedf
# Out:
#         movieId                                              title  \
# 0             1                                   Toy Story (1995)
# 1             1                                   Toy Story (1995)
# 2             1                                   Toy Story (1995)
# 3             1                                   Toy Story (1995)
# 4             1                                   Toy Story (1995)
# ...         ...                                                ...
# 169204   206523  VeggieTales: The Wonderful World Of Auto-tainm...
# 169205   206805                   In the Shadow of the Moon (2019)
# 169206   207309                                   Fractured (2019)
# 169207   207309                                   Fractured (2019)
# 169208   208002                               The Kill Team (2019)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       2     3.5
# ...
